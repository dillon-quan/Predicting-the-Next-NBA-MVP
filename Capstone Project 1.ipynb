# %%
ls
# Out:
# AndroidStudioProjects/       Untitled Folder/
# Applications/                Untitled.ipynb
# Capstone Project 1.ipynb     Untitled1.ipynb
# Desktop/                     Web Scraping Tutorial.ipynb
# Documents/                   Web Scraping.ipynb
# Downloads/                   anaconda/
# Intro Notebook-Copy1.ipynb   matlab_crash_dump.25159-1
# Intro Notebook.ipynb         matlab_crash_dump.2922-1
# Library/                     matlab_crash_dump.319-1
# Movies/                      nltk_data/
# Music/                       octave-workspace
# NBA.db                       rookies.db
# Pictures/                    untitled.txt
# Public/

# %%
cd Downloads
# Out:
# /Users/dillonquan/Downloads

# %%
import pandas as pd
df = pd.read_csv('Seasons_Stats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
df = df.iloc[:,1:]
df.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM',
#        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# The code in the following cell was written to use player data from year 2000 and onward.

# %%
df = df[df.Year >= 2000]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10204 entries, 14470 to 24690
# Data columns (total 52 columns):
# Year      10204 non-null float64
# Player    10204 non-null object
# Pos       10204 non-null object
# Age       10204 non-null float64
# Tm        10204 non-null object
# G         10204 non-null float64
# GS        10204 non-null float64
# MP        10204 non-null float64
# PER       10199 non-null float64
# TS%       10154 non-null float64
# 3PAr      10151 non-null float64
# FTr       10151 non-null float64
# ORB%      10199 non-null float64
# DRB%      10199 non-null float64
# TRB%      10199 non-null float64
# AST%      10199 non-null float64
# STL%      10199 non-null float64
# BLK%      10199 non-null float64
# TOV%      10164 non-null float64
# USG%      10199 non-null float64
# blanl     0 non-null float64
# OWS       10204 non-null float64
# DWS       10204 non-null float64
# WS        10204 non-null float64
# WS/48     10199 non-null float64
# blank2    0 non-null float64
# OBPM      10204 non-null float64
# DBPM      10204 non-null float64
# BPM       10204 non-null float64
# VORP      10204 non-null float64
# FG        10204 non-null float64
# FGA       10204 non-null float64
# FG%       10151 non-null float64
# 3P        10204 non-null float64
# 3PA       10204 non-null float64
# 3P%       8451 non-null float64
# 2P        10204 non-null float64
# 2PA       10204 non-null float64
# 2P%       10129 non-null float64
# eFG%      10151 non-null float64
# FT        10204 non-null float64
# FTA       10204 non-null float64
# FT%       9761 non-null float64
# ORB       10204 non-null float64
# DRB       10204 non-null float64
# TRB       10204 non-null float64
# AST       10204 non-null float64
# STL       10204 non-null float64
# BLK       10204 non-null float64
# TOV       10204 non-null float64
# PF        10204 non-null float64
# PTS       10204 non-null float64
# dtypes: float64(49), object(3)
# memory usage: 4.1+ MB

# %%
pd.options.display.max_columns = None
df.tail()
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0
#
#          TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  \
# 24686  0.604  0.002  0.442   8.6  17.3  12.9   9.1   1.8   3.0  10.9  15.5
# 24687  0.508  0.006  0.247   9.2  17.0  13.2  12.2   0.7   3.3  10.2  16.5
# 24688  0.346  0.000  0.161  10.8  24.9  17.6   5.3   0.9   3.7   8.3  14.8
# 24689  0.503  0.448  0.181   1.9  14.2   8.0   6.1   0.9   1.5  14.4  14.4
# 24690  0.547  0.013  0.206   7.1  21.9  14.3   8.1   1.1   4.4  10.4  20.3
#
#        blanl  OWS  DWS   WS  WS/48  blank2  OBPM  DBPM  BPM  VORP     FG  \
# 24686    NaN  3.4  2.2  5.6  0.157     NaN  -0.2   2.3  2.1   1.8  253.0
# 24687    NaN  0.5  0.6  1.0  0.094     NaN  -3.2   0.8 -2.5  -0.1   78.0
# 24688    NaN -0.1  0.1  0.0 -0.005     NaN  -7.8   0.4 -7.3  -0.1   10.0
# 24689    NaN -0.3  0.8  0.5  0.030     NaN  -3.6  -0.1 -3.7  -0.4   88.0
# 24690    NaN  0.6  0.5  1.1  0.086     NaN  -2.7   0.3 -2.5  -0.1  126.0
#
#          FGA    FG%    3P   3PA    3P%     2P    2PA    2P%   eFG%     FT  \
# 24686  443.0  0.571   0.0   1.0  0.000  253.0  442.0  0.572  0.571  133.0
# 24687  158.0  0.494   0.0   1.0  0.000   78.0  157.0  0.497  0.494   22.0
# 24688   31.0  0.323   0.0   0.0    NaN   10.0   31.0  0.323  0.323    3.0
# 24689  221.0  0.398  33.0  99.0  0.333   55.0  122.0  0.451  0.473   31.0
# 24690  238.0  0.529   0.0   3.0  0.000  126.0  235.0  0.536  0.529   32.0
#
#          FTA    FT%    ORB    DRB    TRB   AST   STL   BLK   TOV     PF    PTS
# 24686  196.0  0.679  135.0  270.0  405.0  99.0  62.0  58.0  65.0  189.0  639.0
# 24687   39.0  0.564   43.0   81.0  124.0  42.0   7.0  21.0  20.0   61.0  178.0
# 24688    5.0  0.600   11.0   24.0   35.0   4.0   2.0   5.0   3.0   17.0   23.0
# 24689   40.0  0.775   15.0  110.0  125.0  36.0  15.0  16.0  40.0   78.0  240.0
# 24690   49.0  0.653   41.0  118.0  159.0  30.0  14.0  33.0  30.0   66.0  284.0

# %% [markdown]
# This cell here was to change certain features from object or float to int type.

# %%
l = ['Year','Age', 'G', 'GS']
for feature in l:
    df[feature] = df[feature].astype(dtype ='int')

# %% [markdown]
# The following converts the basic stat line features from Total to per game stats of each player. The features that were changed are in list to_per_game.

# %%
to_per_game = [ 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA','FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL','BLK', 'TOV', 'PF', 'PTS']
for index,player in df.iterrows():
    for per_game in to_per_game:
        df.loc[index,per_game] = df.loc[index,per_game]/df.loc[index,'G']

# %%
df = df.drop(['blanl','blank2'], axis=1)

# %%
df.head()
# Out:
#        Year               Player Pos  Age   Tm   G  GS         MP   PER  \
# 14470  2000    Tariq Abdul-Wahad  SG   25  TOT  61  56  25.868852  13.6
# 14471  2000    Tariq Abdul-Wahad  SG   25  ORL  46  46  26.195652  14.4
# 14472  2000    Tariq Abdul-Wahad  SG   25  DEN  15  10  24.866667  10.8
# 14473  2000  Shareef Abdur-Rahim  SF   23  VAN  82  82  39.304878  20.2
# 14474  2000       Cory Alexander  PG   26  DEN  29   2  11.344828   8.8
#
#          TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  \
# 14470  0.477  0.036  0.299   7.0  13.1  10.0  10.0   1.8   1.2  12.7  22.5
# 14471  0.484  0.041  0.293   7.0  14.6  10.8   9.7   2.2   0.9  13.0  23.3
# 14472  0.448  0.015  0.321   6.9   8.2   7.6  11.0   0.8   2.2  11.3  19.7
# 14473  0.547  0.075  0.431   8.0  22.7  15.3  15.5   1.5   1.9  14.1  25.0
# 14474  0.381  0.357  0.224   2.6  11.3   6.9  25.7   3.7   0.4  20.6  18.0
#
#        OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP        FG        FGA  \
# 14470  0.4  1.8  2.2  0.068  -1.6   0.1 -1.5   0.2  4.491803  10.590164
# 14471  0.4  1.6  2.0  0.082  -1.3   0.4 -0.8   0.4  4.847826  11.195652
# 14472  0.0  0.2  0.2  0.023  -2.8  -1.0 -3.8  -0.2  3.400000   8.733333
# 14473  6.2  2.6  8.8  0.132   1.8   0.5  2.3   3.5  7.243902  15.573171
# 14474 -0.5  0.4 -0.1 -0.012  -3.6   0.1 -3.5  -0.1  0.965517   3.379310
#
#          FG%        3P       3PA    3P%        2P        2PA    2P%   eFG%  \
# 14470  0.424  0.049180  0.377049  0.130  4.442623  10.213115  0.435  0.426
# 14471  0.433  0.043478  0.456522  0.095  4.804348  10.739130  0.447  0.435
# 14472  0.389  0.066667  0.133333  0.500  3.333333   8.600000  0.388  0.393
# 14473  0.465  0.353659  1.170732  0.302  6.890244  14.402439  0.478  0.477
# 14474  0.286  0.310345  1.206897  0.257  0.655172   2.172414  0.302  0.332
#
#              FT       FTA    FT%       ORB       DRB        TRB       AST  \
# 14470  2.393443  3.163934  0.756  1.655738  3.114754   4.770492  1.606557
# 14471  2.500000  3.282609  0.762  1.673913  3.521739   5.195652  1.565217
# 14472  2.066667  2.800000  0.738  1.600000  1.866667   3.466667  1.733333
# 14473  5.439024  6.719512  0.809  2.658537  7.402439  10.060976  3.304878
# 14474  0.586207  0.758621  0.773  0.275862  1.172414   1.448276  2.000000
#
#             STL       BLK       TOV        PF        PTS
# 14470  0.967213  0.459016  1.737705  2.409836  11.426230
# 14471  1.152174  0.347826  1.891304  2.521739  12.239130
# 14472  0.400000  0.800000  1.266667  2.066667   8.933333
# 14473  1.085366  1.060976  3.036585  2.975610  20.280488
# 14474  0.827586  0.068966  0.965517  1.344828   2.827586

# %%
df['Year1'] = df.Year

# %% [markdown]
# The following cell first groups the dataframe by the year and name of the player and performs a count to discern players that were traded. To mask the dataframe, the index must match the filter so the index was set to do so. Lastly, the dataframe was set such that only players who have played for 1 team that season is left since players that are traded during a season are never MVPs.

# %%
x = df.groupby(['Year','Player']).count()
df = df.set_index(['Year','Player'])
df = df[x.Tm == 1]
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# The following cell here creates a new column MVP for the dataset which contains the values 1 or 0 for MVP and non MVP respectively.

# %%
df['MVP'] = 0
MVP = ["Shaquille O'Neal*", 'Allen Iverson*', 'Tim Duncan','Tim Duncan', 'Kevin Garnett', 'Steve Nash', 'Steve Nash', 'Dirk Nowitzki', 'Kobe Bryant', 'LeBron James','LeBron James','Derrick Rose', 'LeBron James','LeBron James','Kevin Durant','Stephen Curry','Stephen Curry','Russell Westbrook']
Season = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
MVP_winner = list(zip(MVP,Season))
for mvp, year in MVP_winner:
    df.loc[(year,mvp),'MVP'] = 1
    
df_mvps = df[df.MVP == 1]
df_non_mvps = df[df.MVP == 0]
df_mvps = df_mvps.drop('Year1', axis = 1)

# %% [markdown]
# The following cell will randomly sample 99 players from each year from the dataframe that are non_mvps. This newly random sample data will then be concatenated with the dataframe that contains the mvps to have a dataset that is randomly sampled with all MVPs from the year 2000 till present.
#
# Problems:
# -Each time I run the code, the sample is different. Is there a way to sample the same random data each time the code is written?

# %%
df1 = pd.DataFrame()
for year in range(2000,2018):
    random_sample = df_non_mvps.loc[(year,slice(None))].sample(99, replace = False)
    df1 = pd.concat([df1,random_sample], axis = 0)
    
df1 = df1.reset_index()
df1 = df1.rename(columns={'Year1':'Year'})
df1= df1.set_index(['Player','Year'])
df_mvps = df_mvps.swaplevel()
df1 = pd.concat([df1, df_mvps], axis = 0)
df1.head()
# Out:
#                     Pos  Age   Tm   G  GS         MP   PER    TS%   3PAr  \
# Player         Year
# Sean Marks     2000  PF   24  TOR   5   0   2.400000   9.7  0.515  0.167
# Dee Brown      2000  PG   31  TOR  38  12  17.710526  11.8  0.498  0.725
# Dennis Rodman* 2000  PF   38  DAL  12  12  32.416667   8.4  0.457  0.032
# Metta World    2000  SF   20  CHI  72  63  31.083333  13.4  0.491  0.252
# Doug Christie  2000  SG   29  TOR  73  73  31.013699  15.8  0.526  0.360
#
#                        FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  \
# Player         Year
# Sean Marks     2000  0.667   0.0  19.3   9.3   0.0   4.3   5.9  27.9  39.7
# Dee Brown      2000  0.062   1.4   7.7   4.5  20.7   1.9   0.5  12.8  20.0
# Dennis Rodman* 2000  0.452  13.3  33.8  23.6   4.6   0.3   0.2  33.8   6.4
# Metta World    2000  0.368   3.2  13.1   8.1  17.7   2.9   1.3  15.8  21.4
# Doug Christie  2000  0.283   3.0  11.4   7.0  23.0   2.3   1.3  14.4  19.6
#
#                      OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP        FG  \
# Player         Year
# Sean Marks     2000  0.0  0.0  0.0 -0.094 -13.0  -2.9 -15.8   0.0  0.400000
# Dee Brown      2000  0.4  0.4  0.8  0.057   1.3  -3.1  -1.9   0.0  2.447368
# Dennis Rodman* 2000  0.1  0.5  0.6  0.074  -3.6   0.6  -3.0  -0.1  1.000000
# Metta World    2000 -0.3  2.6  2.3  0.050  -1.1   0.8  -0.3   1.0  4.291667
# Doug Christie  2000  3.0  2.0  5.1  0.108   1.6  -0.2   1.4   1.9  4.260274
#
#                            FGA    FG%        3P       3PA    3P%        2P  \
# Player         Year
# Sean Marks     2000   1.200000  0.333  0.000000  0.200000  0.000  0.400000
# Dee Brown      2000   6.789474  0.360  1.763158  4.921053  0.358  0.684211
# Dennis Rodman* 2000   2.583333  0.387  0.000000  0.083333  0.000  1.000000
# Metta World    2000  10.541667  0.407  0.833333  2.652778  0.314  3.458333
