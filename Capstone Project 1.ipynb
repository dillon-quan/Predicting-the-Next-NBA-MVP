# %%
cd Capstone Project 1 Data Files
# Out:
# /Users/dillonquan/Desktop/Capstone Project 1 Data Files

# %%
import pandas as pd
df = pd.read_csv('Seasons_Stats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...    0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...    0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...    0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...    0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...    0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
df = df.iloc[:,1:]
df.head()
#The dataframe had an extra unnamed column that was redundant
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%',
#        '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%',
#        'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM',
#        'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA',
#        '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL',
#        'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %% [markdown]
# The code in the following cell was written to use player data from year 2000 and onward.

# %%
df = df[df.Year >= 1993]
#setting the dataframe to only take players' statline starting from 1993 since this was the rookie season that 
#an MVP had played.

# %%
pd.options.display.max_columns = None
df.tail()
#to show all columns of the dataframe
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0
#
#          TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  \
# 24686  0.604  0.002  0.442   8.6  17.3  12.9   9.1   1.8   3.0  10.9  15.5
# 24687  0.508  0.006  0.247   9.2  17.0  13.2  12.2   0.7   3.3  10.2  16.5
# 24688  0.346  0.000  0.161  10.8  24.9  17.6   5.3   0.9   3.7   8.3  14.8
# 24689  0.503  0.448  0.181   1.9  14.2   8.0   6.1   0.9   1.5  14.4  14.4
# 24690  0.547  0.013  0.206   7.1  21.9  14.3   8.1   1.1   4.4  10.4  20.3
#
#        blanl  OWS  DWS   WS  WS/48  blank2  OBPM  DBPM  BPM  VORP     FG  \
# 24686    NaN  3.4  2.2  5.6  0.157     NaN  -0.2   2.3  2.1   1.8  253.0
# 24687    NaN  0.5  0.6  1.0  0.094     NaN  -3.2   0.8 -2.5  -0.1   78.0
# 24688    NaN -0.1  0.1  0.0 -0.005     NaN  -7.8   0.4 -7.3  -0.1   10.0
# 24689    NaN -0.3  0.8  0.5  0.030     NaN  -3.6  -0.1 -3.7  -0.4   88.0
# 24690    NaN  0.6  0.5  1.1  0.086     NaN  -2.7   0.3 -2.5  -0.1  126.0
#
#          FGA    FG%    3P   3PA    3P%     2P    2PA    2P%   eFG%     FT  \
# 24686  443.0  0.571   0.0   1.0  0.000  253.0  442.0  0.572  0.571  133.0
# 24687  158.0  0.494   0.0   1.0  0.000   78.0  157.0  0.497  0.494   22.0
# 24688   31.0  0.323   0.0   0.0    NaN   10.0   31.0  0.323  0.323    3.0
# 24689  221.0  0.398  33.0  99.0  0.333   55.0  122.0  0.451  0.473   31.0
# 24690  238.0  0.529   0.0   3.0  0.000  126.0  235.0  0.536  0.529   32.0
#
#          FTA    FT%    ORB    DRB    TRB   AST   STL   BLK   TOV     PF    PTS
# 24686  196.0  0.679  135.0  270.0  405.0  99.0  62.0  58.0  65.0  189.0  639.0
# 24687   39.0  0.564   43.0   81.0  124.0  42.0   7.0  21.0  20.0   61.0  178.0
# 24688    5.0  0.600   11.0   24.0   35.0   4.0   2.0   5.0   3.0   17.0   23.0
# 24689   40.0  0.775   15.0  110.0  125.0  36.0  15.0  16.0  40.0   78.0  240.0
# 24690   49.0  0.653   41.0  118.0  159.0  30.0  14.0  33.0  30.0   66.0  284.0

# %% [markdown]
# This cell here was to change certain features from object or float to int type.

# %%
l = ['Year','Age', 'G', 'GS']
for feature in l:
    df[feature] = df[feature].astype(dtype ='int')
#casting these columsn to be of type int

# %% [markdown]
# The following converts the basic stat line features from Total to per game stats of each player. The features that were changed are in list to_per_game.

# %%
to_per_game = [ 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA','FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL','BLK', 'TOV', 'PF', 'PTS']
for index,player in df.iterrows():
    for per_game in to_per_game:
        df.loc[index,per_game] = df.loc[index,per_game]/df.loc[index,'G']

#This nested for loop helps turn the total stats for the season to per game stats for the season for readability

# %%
df = df.drop(['blanl','blank2'], axis=1)
#dropping two empty columns

# %%
df.head()
# Out:
#        Year              Player Pos  Age   Tm   G  GS         MP   PER    TS%  \
# 10908  1993      Alaa Abdelnaby  PF   24  TOT  75  52  17.480000  13.2  0.551
# 10909  1993      Alaa Abdelnaby  PF   24  MIL  12   0  13.250000  11.9  0.508
# 10910  1993      Alaa Abdelnaby  PF   24  BOS  63  52  18.285714  13.4  0.557
# 10911  1993  Mahmoud Abdul-Rauf  PG   23  DEN  81  81  33.456790  15.6  0.515
# 10912  1993          Mark Acres   C   30  TOT  18   7  14.944444   8.9  0.571
#
#         3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS  \
# 10908  0.002  0.245  11.0  18.1  14.6   3.0   1.0   1.2  15.6  20.5  0.7  1.3
# 10909  0.018  0.286   8.6  18.3  13.4   9.5   1.9   1.6  17.1  20.5  0.0  0.2
# 10910  0.000  0.240  11.3  18.1  14.8   2.2   0.8   1.2  15.4  20.5  0.7  1.2
# 10911  0.140  0.165   2.0   6.8   4.4  20.8   1.5   0.2  11.0  25.5  3.0  2.2
# 10912  0.041  0.327  10.8  17.4  14.0   2.5   0.5   1.4  18.8  11.0  0.1  0.2
#
#         WS  WS/48  OBPM  DBPM  BPM  VORP        FG        FGA    FG%  \
# 10908  2.0  0.074  -2.3  -1.9 -4.2  -0.7  3.266667   6.306667  0.518
# 10909  0.1  0.035  -3.7  -0.5 -4.3  -0.1  2.166667   4.666667  0.464
# 10910  1.9  0.079  -2.1  -2.1 -4.1  -0.6  3.476190   6.619048  0.525
# 10911  5.1  0.091   1.1  -2.1 -1.0   0.7  7.814815  17.370370  0.450
# 10912  0.3  0.056  -3.5  -1.3 -4.9  -0.2  1.444444   2.722222  0.531
#
#              3P       3PA    3P%        2P        2PA    2P%   eFG%        FT  \
# 10908  0.000000  0.013333  0.000  3.266667   6.293333  0.519  0.518  1.173333
# 10909  0.000000  0.083333  0.000  2.166667   4.583333  0.473  0.464  1.000000
# 10910  0.000000  0.000000    NaN  3.476190   6.619048  0.525  0.525  1.206349
# 10911  0.864198  2.432099  0.355  6.950617  14.938272  0.465  0.475  2.679012
# 10912  0.055556  0.111111  0.500  1.388889   2.611111  0.532  0.541  0.611111
#
#             FTA    FT%       ORB       DRB       TRB       AST       STL  \
# 10908  1.546667  0.759  1.680000  2.813333  4.493333  0.360000  0.333333
# 10909  1.333333  0.750  1.000000  2.083333  3.083333  0.833333  0.500000
# 10910  1.587302  0.760  1.809524  2.952381  4.761905  0.269841  0.301587
# 10911  2.864198  0.935  0.629630  2.148148  2.777778  4.246914  1.037037
# 10912  0.888889  0.688  1.444444  2.277778  3.722222  0.277778  0.166667
#
#             BLK       TOV        PF        PTS
# 10908  0.346667  1.293333  2.520000   7.706667
# 10909  0.333333  1.083333  2.000000   5.333333
# 10910  0.349206  1.333333  2.619048   8.158730
# 10911  0.098765  2.308642  2.209877  19.172840
# 10912  0.333333  0.722222  1.888889   3.555556

# %%
df['Year1'] = df.Year
#a copy of the year column was created as this column will not be present after sampling

# %% [markdown]
# The following cell reads another csv file to retrieve the win lose ratio for each team from the 2000 to 2017 season. The team_win_ratio.csv file was scraped from basketball reference. The jupyter page for this is also submitted in the other link.

# %%
df.head()
# Out:
#        Year              Player Pos  Age   Tm   G  GS         MP   PER    TS%  \
# 10908  1993      Alaa Abdelnaby  PF   24  TOT  75  52  17.480000  13.2  0.551
# 10909  1993      Alaa Abdelnaby  PF   24  MIL  12   0  13.250000  11.9  0.508
# 10910  1993      Alaa Abdelnaby  PF   24  BOS  63  52  18.285714  13.4  0.557
# 10911  1993  Mahmoud Abdul-Rauf  PG   23  DEN  81  81  33.456790  15.6  0.515
# 10912  1993          Mark Acres   C   30  TOT  18   7  14.944444   8.9  0.571
#
#         3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS  \
# 10908  0.002  0.245  11.0  18.1  14.6   3.0   1.0   1.2  15.6  20.5  0.7  1.3
# 10909  0.018  0.286   8.6  18.3  13.4   9.5   1.9   1.6  17.1  20.5  0.0  0.2
# 10910  0.000  0.240  11.3  18.1  14.8   2.2   0.8   1.2  15.4  20.5  0.7  1.2
# 10911  0.140  0.165   2.0   6.8   4.4  20.8   1.5   0.2  11.0  25.5  3.0  2.2
# 10912  0.041  0.327  10.8  17.4  14.0   2.5   0.5   1.4  18.8  11.0  0.1  0.2
#
#         WS  WS/48  OBPM  DBPM  BPM  VORP        FG        FGA    FG%  \
# 10908  2.0  0.074  -2.3  -1.9 -4.2  -0.7  3.266667   6.306667  0.518
# 10909  0.1  0.035  -3.7  -0.5 -4.3  -0.1  2.166667   4.666667  0.464
# 10910  1.9  0.079  -2.1  -2.1 -4.1  -0.6  3.476190   6.619048  0.525
# 10911  5.1  0.091   1.1  -2.1 -1.0   0.7  7.814815  17.370370  0.450
# 10912  0.3  0.056  -3.5  -1.3 -4.9  -0.2  1.444444   2.722222  0.531
#
#              3P       3PA    3P%        2P        2PA    2P%   eFG%        FT  \
# 10908  0.000000  0.013333  0.000  3.266667   6.293333  0.519  0.518  1.173333
# 10909  0.000000  0.083333  0.000  2.166667   4.583333  0.473  0.464  1.000000
# 10910  0.000000  0.000000    NaN  3.476190   6.619048  0.525  0.525  1.206349
# 10911  0.864198  2.432099  0.355  6.950617  14.938272  0.465  0.475  2.679012
# 10912  0.055556  0.111111  0.500  1.388889   2.611111  0.532  0.541  0.611111
#
#             FTA    FT%       ORB       DRB       TRB       AST       STL  \
# 10908  1.546667  0.759  1.680000  2.813333  4.493333  0.360000  0.333333
# 10909  1.333333  0.750  1.000000  2.083333  3.083333  0.833333  0.500000
# 10910  1.587302  0.760  1.809524  2.952381  4.761905  0.269841  0.301587
# 10911  2.864198  0.935  0.629630  2.148148  2.777778  4.246914  1.037037
# 10912  0.888889  0.688  1.444444  2.277778  3.722222  0.277778  0.166667
#
#             BLK       TOV        PF        PTS  Year1
# 10908  0.346667  1.293333  2.520000   7.706667   1993
# 10909  0.333333  1.083333  2.000000   5.333333   1993
# 10910  0.349206  1.333333  2.619048   8.158730   1993
# 10911  0.098765  2.308642  2.209877  19.172840   1993
# 10912  0.333333  0.722222  1.888889   3.555556   1993

# %%
df_team = pd.read_csv('team_win_ratio.csv')
df_team = df_team.iloc[:, 2:]
df_team1 = df_team[['Team','Year', 'W/L%']]
df_team1 = df_team1.rename(columns={'Team':'Tm'})
df = pd.merge(df, df_team1, how ='left', on=['Tm', 'Year'])
#Read in the team_win_ratio csv file that was scraped shown in the other jupyter notebook to merge it with
#the Season Stats dataframe

# %%
df.head()
# Out:
#    Year              Player Pos  Age   Tm   G  GS         MP   PER    TS%  \
# 0  1993      Alaa Abdelnaby  PF   24  TOT  75  52  17.480000  13.2  0.551
# 1  1993      Alaa Abdelnaby  PF   24  MIL  12   0  13.250000  11.9  0.508
# 2  1993      Alaa Abdelnaby  PF   24  BOS  63  52  18.285714  13.4  0.557
# 3  1993  Mahmoud Abdul-Rauf  PG   23  DEN  81  81  33.456790  15.6  0.515
# 4  1993          Mark Acres   C   30  TOT  18   7  14.944444   8.9  0.571
#
#     3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  OWS  DWS  \
# 0  0.002  0.245  11.0  18.1  14.6   3.0   1.0   1.2  15.6  20.5  0.7  1.3
# 1  0.018  0.286   8.6  18.3  13.4   9.5   1.9   1.6  17.1  20.5  0.0  0.2
# 2  0.000  0.240  11.3  18.1  14.8   2.2   0.8   1.2  15.4  20.5  0.7  1.2
# 3  0.140  0.165   2.0   6.8   4.4  20.8   1.5   0.2  11.0  25.5  3.0  2.2
# 4  0.041  0.327  10.8  17.4  14.0   2.5   0.5   1.4  18.8  11.0  0.1  0.2
#
#     WS  WS/48  OBPM  DBPM  BPM  VORP        FG        FGA    FG%        3P  \
# 0  2.0  0.074  -2.3  -1.9 -4.2  -0.7  3.266667   6.306667  0.518  0.000000
# 1  0.1  0.035  -3.7  -0.5 -4.3  -0.1  2.166667   4.666667  0.464  0.000000
# 2  1.9  0.079  -2.1  -2.1 -4.1  -0.6  3.476190   6.619048  0.525  0.000000
# 3  5.1  0.091   1.1  -2.1 -1.0   0.7  7.814815  17.370370  0.450  0.864198
# 4  0.3  0.056  -3.5  -1.3 -4.9  -0.2  1.444444   2.722222  0.531  0.055556
#
#         3PA    3P%        2P        2PA    2P%   eFG%        FT       FTA  \
# 0  0.013333  0.000  3.266667   6.293333  0.519  0.518  1.173333  1.546667
# 1  0.083333  0.000  2.166667   4.583333  0.473  0.464  1.000000  1.333333
# 2  0.000000    NaN  3.476190   6.619048  0.525  0.525  1.206349  1.587302
# 3  2.432099  0.355  6.950617  14.938272  0.465  0.475  2.679012  2.864198
# 4  0.111111  0.500  1.388889   2.611111  0.532  0.541  0.611111  0.888889
#
#      FT%       ORB       DRB       TRB       AST       STL       BLK  \
# 0  0.759  1.680000  2.813333  4.493333  0.360000  0.333333  0.346667
# 1  0.750  1.000000  2.083333  3.083333  0.833333  0.500000  0.333333
# 2  0.760  1.809524  2.952381  4.761905  0.269841  0.301587  0.349206
# 3  0.935  0.629630  2.148148  2.777778  4.246914  1.037037  0.098765
# 4  0.688  1.444444  2.277778  3.722222  0.277778  0.166667  0.333333
#
#         TOV        PF        PTS  Year1  W/L%
# 0  1.293333  2.520000   7.706667   1993   NaN
# 1  1.083333  2.000000   5.333333   1993   NaN
# 2  1.333333  2.619048   8.158730   1993   NaN
# 3  2.308642  2.209877  19.172840   1993   NaN
# 4  0.722222  1.888889   3.555556   1993   NaN

# %% [markdown]
# The following cell first groups the dataframe by the year and name of the player and performs a count to find players that were traded. To mask the dataframe, the index must match the filter so the index was set to do so. Lastly, the dataframe was set such that only players who have played for 1 team that season is left since players that are traded during a season are never MVPs.

# %%
x = df.groupby(['Year','Player']).count()
df = df.set_index(['Year','Player'])
df = df[x.Tm == 1]
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# The following cell here creates a new column MVP for the dataset which contains the values 1 or 0 for MVP and non MVP respectively.

# %%
df['MVP'] = 0
MVP = ["Shaquille O'Neal*", 'Allen Iverson*', 'Tim Duncan','Tim Duncan', 'Kevin Garnett', 'Steve Nash', 'Steve Nash', 'Dirk Nowitzki', 'Kobe Bryant', 'LeBron James','LeBron James','Derrick Rose', 'LeBron James','LeBron James','Kevin Durant','Stephen Curry','Stephen Curry','Russell Westbrook']
Season = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
MVP_winner = list(zip(MVP,Season))
for mvp, year in MVP_winner:
    df.loc[(year,mvp),'MVP'] = 1
    
df_mvps = df[df.MVP == 1]
df_non_mvps = df[df.MVP == 0]
df_mvps = df_mvps.drop('Year1', axis = 1)

#This cell here creates a new column called MVP and each player will have either a 1 if they won MVP that season or 
#a 0 if they did not

# %%
df.head()
# Out:
#                         Pos  Age   Tm   G  GS         MP   PER    TS%   3PAr  \
# Year Player
# 1993 Mahmoud Abdul-Rauf  PG   23  DEN  81  81  33.456790  15.6  0.515  0.140
#      Michael Adams       PG   30  WSB  70  70  35.700000  15.6  0.543  0.255
#      Rafael Addison      SF   28  NJN  68  15  17.117647   8.4  0.484  0.083
#      Mark Aguirre        SF   33  DET  51  15  20.705882  13.7  0.525  0.197
#      Danny Ainge         SG   33  PHO  80   0  27.037500  14.3  0.596  0.510
#
#                            FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  \
# Year Player
# 1993 Mahmoud Abdul-Rauf  0.165   2.0   6.8   4.4  20.8   1.5   0.2  11.0
#      Michael Adams       0.333   2.3   8.6   5.4  30.6   2.0   0.1  15.5
#      Rafael Addison      0.170   4.2   8.2   6.2   6.8   1.0   0.6  12.7
#      Mark Aguirre        0.306   4.3  12.0   8.0  15.3   0.8   0.4  12.4
#      Danny Ainge         0.199   2.6   8.3   5.5  16.5   1.5   0.2  12.5
#
#                          USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP  \
# Year Player
# 1993 Mahmoud Abdul-Rauf  25.5  3.0  2.2  5.1  0.091   1.1  -2.1 -1.0   0.7
#      Michael Adams       19.2  3.3  1.2  4.6  0.088   1.6  -1.6 -0.1   1.2
#      Rafael Addison      18.2 -0.1  1.0  0.9  0.038  -3.4  -1.2 -4.6  -0.8
#      Mark Aguirre        22.2  1.1  0.7  1.8  0.082  -0.3  -1.3 -1.5   0.1
#      Danny Ainge         17.3  4.5  1.8  6.2  0.139   3.0  -1.3  1.6   2.0
#
#                                FG        FGA    FG%        3P       3PA  \
# Year Player
# 1993 Mahmoud Abdul-Rauf  7.814815  17.370370  0.450  0.864198  2.432099
#      Michael Adams       5.214286  11.871429  0.439  0.971429  3.028571
#      Rafael Addison      2.676471   6.044118  0.443  0.102941  0.500000
#      Mark Aguirre        3.666667   8.274510  0.443  0.588235  1.627451
#      Danny Ainge         4.212500   9.125000  0.462  1.875000  4.650000
#
#                            3P%        2P        2PA    2P%   eFG%        FT  \
# Year Player
# 1993 Mahmoud Abdul-Rauf  0.355  6.950617  14.938272  0.465  0.475  2.679012
#      Michael Adams       0.321  4.242857   8.842857  0.480  0.480  3.385714
#      Rafael Addison      0.206  2.573529   5.544118  0.464  0.451  0.838235
#      Mark Aguirre        0.361  3.078431   6.647059  0.463  0.479  1.941176
#      Danny Ainge         0.403  2.337500   4.475000  0.522  0.564  1.537500
#
#                               FTA    FT%       ORB       DRB       TRB  \
# Year Player
# 1993 Mahmoud Abdul-Rauf  2.864198  0.935  0.629630  2.148148  2.777778
#      Michael Adams       3.957143  0.856  0.742857  2.685714  3.428571
#      Rafael Addison      1.029412  0.814  0.661765  1.279412  1.941176
#      Mark Aguirre        2.529412  0.767  0.843137  2.137255  2.980392
#      Danny Ainge         1.812500  0.848  0.612500  2.062500  2.675000
#
#                               AST       STL       BLK       TOV        PF  \
# Year Player
# 1993 Mahmoud Abdul-Rauf  4.246914  1.037037  0.098765  2.308642  2.209877
#      Michael Adams       7.514286  1.428571  0.057143  2.500000  2.085714
#      Rafael Addison      0.779412  0.338235  0.161765  0.941176  1.838235
#      Mark Aguirre        2.058824  0.313725  0.137255  1.333333  1.980392
#      Danny Ainge         3.250000  0.862500  0.100000  1.412500  2.187500
#
#                                PTS  Year1  W/L%  MVP
# Year Player
# 1993 Mahmoud Abdul-Rauf  19.172840   1993   NaN    0
#      Michael Adams       14.785714   1993   NaN    0
#      Rafael Addison       6.294118   1993   NaN    0
#      Mark Aguirre         9.862745   1993   NaN    0
#      Danny Ainge         11.837500   1993   NaN    0

# %% [markdown]
# The following cell will randomly sample 99 players from each year from the non_mvps dataframe. This randomly sampled dataframe will then be concatenated with the mvp dataframe to have a dataset that is ready for classification.

# %%
df1 = pd.DataFrame()
for year in range(2000,2018):
    random_sample = df_non_mvps.loc[(year,slice(None))].sample(99, replace = False, random_state = 4)
    df1 = pd.concat([df1,random_sample], axis = 0)
    
df1 = df1.reset_index()
df1 = df1.rename(columns={'Year1':'Year'})
df1= df1.set_index(['Player','Year'])
df_mvps = df_mvps.swaplevel()
df1 = pd.concat([df1, df_mvps], axis = 0)
df1.head()

#df1 contains the randomly sampled data that will be used to train our model with to classify MVPs and non MVPs
# Out:
#                     Pos  Age   Tm   G  GS         MP   PER    TS%   3PAr  \
# Player         Year
# Kevin Willis   2000  PF   37  TOR  79   1  21.253165  12.3  0.471  0.005
# Kenny Anderson 2000  PG   29  BOS  82  82  31.621951  17.4  0.524  0.223
# Randy Brown    2000  PG   31  CHI  59  55  27.542373   7.3  0.402  0.014
# Allen Iverson* 2000  SG   24  PHI  70  70  40.757143  20.0  0.496  0.151
# Vince Carter   2000  SF   23  TOR  82  82  38.121951  23.4  0.543  0.139
#
#                        FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  \
# Player         Year
# Kevin Willis   2000  0.288  13.0  19.4  16.1   4.8   1.1   2.0  13.3  19.5
# Kenny Anderson 2000  0.257   2.3   7.9   4.9  26.7   2.7   0.2  10.6  20.5
# Randy Brown    2000  0.193   1.6   8.9   5.2  22.6   2.0   0.7  18.2  16.2
# Allen Iverson* 2000  0.358   2.7   7.7   5.2  23.0   2.6   0.1  10.3  34.4
# Vince Carter   2000  0.325   5.2  12.1   8.5  20.5   1.8   2.1   8.4  30.0
#
#                      OWS  DWS    WS  WS/48  OBPM  DBPM  BPM  VORP         FG  \
# Player         Year
# Kevin Willis   2000  0.7  1.6   2.3  0.066  -3.1  -1.2 -4.4  -1.0   2.987342
# Kenny Anderson 2000  5.4  1.9   7.3  0.136   2.6  -1.4  1.2   2.1   5.292683
# Randy Brown    2000 -2.0  1.2  -0.8 -0.024  -5.2  -0.5 -5.7  -1.5   2.661017
# Allen Iverson* 2000  3.3  3.6   6.9  0.116   3.4  -0.8  2.6   3.3  10.414286
# Vince Carter   2000  9.1  2.7  11.8  0.182   5.2  -0.6  4.6   5.2   9.609756
#
#                            FGA    FG%        3P       3PA    3P%        2P  \
# Player         Year
# Kevin Willis   2000   7.202532  0.415  0.012658  0.037975  0.333  2.974684
# Kenny Anderson 2000  12.024390  0.440  1.036585  2.682927  0.386  4.256098
# Randy Brown    2000   7.372881  0.361  0.050847  0.101695  0.500  2.610169
# Allen Iverson* 2000  24.757143  0.421  1.271429  3.728571  0.341  9.142857
# Vince Carter   2000  20.682927  0.465  1.158537  2.878049  0.403  8.451220
#
#                            2PA    2P%   eFG%        FT       FTA    FT%  \
# Player         Year
# Kevin Willis   2000   7.164557  0.415  0.416  1.658228  2.075949  0.799
# Kenny Anderson 2000   9.341463  0.456  0.483  2.390244  3.085366  0.775
# Randy Brown    2000   7.271186  0.359  0.364  1.050847  1.423729  0.738
# Allen Iverson* 2000  21.028571  0.435  0.446  6.314286  8.857143  0.713
# Vince Carter   2000  17.804878  0.475  0.493  5.317073  6.719512  0.791
#
#                           ORB       DRB       TRB       AST       STL  \
# Player         Year
# Kevin Willis   2000  2.544304  3.556962  6.101266  0.620253  0.455696
# Kenny Anderson 2000  0.670732  2.073171  2.743902  5.121951  1.695122
# Randy Brown    2000  0.389831  2.050847  2.440678  3.423729  1.033898
# Allen Iverson* 2000  1.014286  2.800000  3.814286  4.685714  2.057143
# Vince Carter   2000  1.829268  3.975610  5.804878  3.926829  1.341463
#
#                           BLK       TOV        PF        PTS   W/L%  MVP
# Player         Year
# Kevin Willis   2000  0.607595  1.240506  3.240506   7.645570  0.549    0
# Kenny Anderson 2000  0.097561  1.585366  2.804878  14.012195  0.427    0
# Randy Brown    2000  0.254237  1.779661  2.033898   6.423729  0.207    0
# Allen Iverson* 2000  0.071429  3.285714  2.314286  28.414286  0.598    0
# Vince Carter   2000  1.121951  2.170732  3.207317  25.695122  0.549    0

# %% [markdown]
# The following three cells were used to help combine the MVP and non MVP dataset so that statistical analysis and EDA  can be done on the clean data set.

# %%
df_mvp1 = df_mvps

# %%
df_mvp1 = df_mvp1.swaplevel()

# %%
df_clean = pd.concat([df_mvp1,df_non_mvps], axis = 0)
df_clean.to_csv('Clean NBA Player Data.csv')
